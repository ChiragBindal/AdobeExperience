# %%
# 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

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 19.6 MB/s eta 0:00:00
# ...

# %%
import os
import openai
openai.api_key = "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"


def ASK_GPT(PROMPT):
  response = openai.Completion.create(
  engine="text-davinci-002",
  prompt =  PROMPT,
  temperature = 0.6,
  top_p = 1,
  max_tokens = 100,
  frequency_penalty = 0,
  presence_penalty = 0
  )
  return response.choices[0].text

import requests
from PIL import Image
from io import BytesIO


def generate_dalle(PROMPT):
    response = openai.Image.create(
        prompt= PROMPT,
        n=1,
        size="512x512",
    )
    image_url = response['data'][0]['url']


    image_data = requests.get(image_url).content


    image = Image.open(BytesIO(image_data))


    image.save('generated_image.jpg')
    image.show()

# %%
def generatead(prodesc, tags):
  prompt =prodesc+' using keywords '+tags+' Create an advertisement text for given product that effectively communicates its key features and benefits to potential customers. The text should be persuasive and engaging, encouraging the reader to take action and purchase the product.The text should be clear, concise, and free of errors or grammatical mistakes.' 
  return print(ASK_GPT(prompt))

def create_img(prodesc):
  prompt=prodesc+'"Create an image of this product in use, showcasing its key features and benefits, visually appealing and eye-catching, with a focus on highlighting the unique qualities of the product'
  generate_dalle(prompt)

tags = 'apollo, classical, movie, united, sport, show, thriller, site, grocery, america'
prodesc = 'Comfortable, casual, and loose-fitting, our heavyweight dark color t-shirt '
generatead(prodesc,tags)
create_img(prodesc)
# Out:
# Looking for a comfortable, casual, and loose-fitting t-shirt? Look no further than our heavyweight dark color t-shirt! Made of 100% cotton, this t-shirt is sure to keep you comfortable all day long. Plus, our t-shirt is machine-washable for easy care.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F372E5F5C00>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F372E5F5C00>
